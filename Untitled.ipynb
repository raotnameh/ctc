# %%
import math

# %%
def lse(*args): # logsumexp trick
    a_max = max(args)
    lsp = math.log(sum(math.exp(a-a_max) for a in args))
    return a_max + lsp

# %%
lse(0.009,0.009)
# Out:
# 0.7021471805599453

# %%
0.09*0.09
# Out:
# 0.0081

# %%
for i in range(1000):
    print(lse(0.9**i,0.9**i), "---", 0.9**i*0.9**i)
# Out:
# 1.6931471805599454 --- 1.0
# 1.5931471805599453 --- 0.81
# 1.5031471805599455 --- 0.6561000000000001
# 1.4221471805599455 --- 0.5314410000000002
# 1.3492471805599453 --- 0.43046721000000004
# 1.2836371805599454 --- 0.3486784401000001
# 1.2245881805599454 --- 0.28242953648100005
# 1.1714440805599453 --- 0.22876792454961006
# 1.1236143905599454 --- 0.1853020188851842
# 1.0805676695599453 --- 0.15009463529699918
# 1.0418256206599454 --- 0.12157665459056935
# 1.0069577766499453 --- 0.09847709021836117
# 0.9755767170409454 --- 0.07976644307687257
# 0.9473337633928454 --- 0.06461081889226677
# 0.9219151051095553 --- 0.05233476330273609
# 0.8990383126545943 --- 0.04239115827521623
# 0.8784491994451294 --- 0.03433683820292515
# 0.859918997556611 --- 0.027812838944369377
# 0.8432418158569445 --- 0.022528399544939192
# 0.8282323523272446 --- 0.01824800363140075
# 0.8147238351505146 --- 0.014780882941434608
# 0.8025661696914577 --- 0.011972515182562033
# ...
